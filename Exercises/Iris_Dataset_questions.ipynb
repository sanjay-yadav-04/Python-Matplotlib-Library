# %% [markdown]
# # Iris Dataset Exercises
#
# Practice NumPy, Pandas, Matplotlib, and Seaborn using the Iris dataset.
#
# **Difficulty:** Easy → Moderate

# %% [markdown]
# # Iris Dataset Exercises
#
# Practice NumPy, Pandas, Matplotlib, and Seaborn using the Iris dataset.
#
# **Difficulty:** Easy → Moderate

# %% [markdown]
# # Iris Dataset Exercises
#
# Practice NumPy, Pandas, Matplotlib, and Seaborn using the Iris dataset.
#
# **Difficulty:** Easy → Moderate

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

plt.style.use('ggplot')

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df["species"] = iris.target_names[iris.target]
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ## Exercise 1
#
# **Question:** Display the first 10 rows of the dataset.

# %%
df.head(10)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
# 5  setosa
# 6  setosa
# 7  setosa
# 8  setosa
# 9  setosa

# %% [markdown]
# ## Exercise 2
#
# **Question:** Display the last 5 rows.

# %%
df.tail(5)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica

# %% [markdown]
# ## Exercise 3
#
# **Question:** Find the number of rows, columns, and column names.

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# ## Exercise 4
#
# **Question:** Display basic information about the dataset.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %% [markdown]
# ## Exercise 5
#
# **Question:** Generate descriptive statistics of all numerical columns.

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# ## Exercise 6
#
# **Question:** Convert the feature columns into a NumPy array and display its shape and data type.

# %%
x=df.iloc[:,:-1].to_numpy()
print(x.shape)
# Out:
# (150, 4)

# %% [markdown]
# ## Exercise 7
#
# **Question:** Calculate the mean of each feature using NumPy.

# %%
x=df.iloc[:,:-1].mean()
x
# Out:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64

# %% [markdown]
# ## Exercise 8
#
# **Question:** Calculate the minimum and maximum value of each feature.

# %%
x=df.iloc[:,:-1].min
y=df.iloc[:,:-1].max

# %% [markdown]
# ## Exercise 9
#
# **Question:** Find the standard deviation of each feature.

# %% [markdown]
# ## Exercise 10
#
# **Question:** How many samples belong to each species?

# %% [markdown]
# ## Exercise 11
#
# **Question:** Find the average sepal length for each species.

# %% [markdown]
# ## Exercise 12
#
# **Question:** Find the maximum petal length for each species.

# %% [markdown]
# ## Exercise 13
#
# **Question:** Sort the dataset by petal width in descending order.

# %% [markdown]
# ## Exercise 14
#
# **Question:** Display only the samples where sepal length is greater than 6 cm.

# %% [markdown]
# ## Exercise 15
#
# **Question:** Plot a histogram of sepal length.

# %% [markdown]
# ## Exercise 16
#
# **Question:** Plot a scatter plot of sepal length vs petal length.

# %% [markdown]
# ## Exercise 17
#
# **Question:** Create a bar chart showing the number of samples in each species.

# %% [markdown]
# ## Exercise 18
#
# **Question:** Create a count plot for species.

# %% [markdown]
# ## Exercise 19
#
# **Question:** Create a boxplot of petal length grouped by species.

# %% [markdown]
# ## Exercise 20
#
# **Question:** Create a pairplot colored by species.

# %% [markdown]
# ## Exercise 21
#
# **Question:** Find the correlation matrix of the numerical columns.

# %% [markdown]
# ## Exercise 22
#
# **Question:** Visualize the correlation matrix using a heatmap.

# %% [markdown]
# ## Exercise 23
#
# **Question:** Find the species with the highest average petal width.

# %% [markdown]
# ## Exercise 24
#
# **Question:** Create a new column called Petal Area = Petal Length × Petal Width.

# %% [markdown]
# ## Exercise 25
#
# **Question:** Find the top 5 flowers having the largest Petal Area.

# %% [markdown]
# ## Exercise 26
#
# **Question:** Find the average of all numerical features for each species.

# %% [markdown]
# ## Exercise 27
#
# **Question:** Find all flowers whose petal length is above the dataset average.

# %% [markdown]
# ## Exercise 28
#
# **Question:** Create a violin plot of sepal width grouped by species.

# %% [markdown]
# ## Exercise 29
#
# **Question:** Create a scatter plot of sepal length vs petal length using different colors for each species.

# %% [markdown]
# ## Exercise 30
#
# **Question:** For each species, find the average of each numerical feature and the number of samples in a single table.
